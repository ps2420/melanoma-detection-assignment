# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# **The dataset** consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
#
# The data set contains the following diseases:
#
# 1. Actinic keratosis
# 2. Basal cell carcinoma
# 3. Dermatofibroma
# 4. Melanoma
# 5. Nevus
# 6. Pigmented benign keratosis
# 7. Seborrheic keratosis
# 8. Squamous cell carcinoma
# 9. Vascular lesion

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D, MaxPool2D

# %%
## mount the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Check for default google drive directory
# !ls
# Out:
# gdrive	sample_data

# %% [markdown]
# ### Data Summary
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the root path for train and test images 
root_path = '/content/gdrive/My Drive/cnn-melanoma-detection'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
# Print the number of tran and test images
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Load the train dataset, and use validation_split 0.2 while definiting
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split = 0.2,
    subset = "training",
    seed = 123,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split = 0.2,
    subset = "validation",
    seed = 123,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
#check the tensor shape
print(train_ds)
print(val_ds)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# print the class available in dataset (dataset should consist of 9 classes)

# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.

class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
# Define the test_ds from data_dir_test

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )
# Out:
# Found 118 files belonging to 9 classes.

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    ax.set_title(class_names[labels[i]])
plt.show()

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
# Rescale the image
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

input_shape = (180,180,3)
num_classes = 9

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(
    optimizer ='adam', 
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy']
)

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 512)               31719936
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 31,827,049
# Trainable params: 31,827,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20 
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 479s 2s/step - loss: 2.2156 - accuracy: 0.1869 - val_loss: 2.0359 - val_accuracy: 0.1924
# Epoch 2/20
# 56/56 [==============================] - 2s 41ms/step - loss: 2.0047 - accuracy: 0.2210 - val_loss: 1.9479 - val_accuracy: 0.2953
# Epoch 3/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.8651 - accuracy: 0.2963 - val_loss: 1.8451 - val_accuracy: 0.3535
# Epoch 4/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.6418 - accuracy: 0.4185 - val_loss: 1.4960 - val_accuracy: 0.4944
# Epoch 5/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.5352 - accuracy: 0.4743 - val_loss: 1.4081 - val_accuracy: 0.4989
# Epoch 6/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3881 - accuracy: 0.5190 - val_loss: 1.3948 - val_accuracy: 0.5235
# Epoch 7/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3210 - accuracy: 0.5480 - val_loss: 1.6062 - val_accuracy: 0.4653
# Epoch 8/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.3127 - accuracy: 0.5530 - val_loss: 1.3601 - val_accuracy: 0.5280
# Epoch 9/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2211 - accuracy: 0.5831 - val_loss: 1.4088 - val_accuracy: 0.5347
# Epoch 10/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.1857 - accuracy: 0.5843 - val_loss: 1.6290 - val_accuracy: 0.4698
# Epoch 11/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0957 - accuracy: 0.6211 - val_loss: 1.3948 - val_accuracy: 0.5481
# Epoch 12/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0321 - accuracy: 0.6362 - val_loss: 1.4614 - val_accuracy: 0.5213
# Epoch 13/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.9583 - accuracy: 0.6590 - val_loss: 1.4573 - val_accuracy: 0.5078
# Epoch 14/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.9973 - accuracy: 0.6479 - val_loss: 1.5720 - val_accuracy: 0.4832
# Epoch 15/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.9170 - accuracy: 0.6730 - val_loss: 1.7538 - val_accuracy: 0.4609
# Epoch 16/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.8502 - accuracy: 0.6920 - val_loss: 1.6708 - val_accuracy: 0.5190
# Epoch 17/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.7910 - accuracy: 0.7210 - val_loss: 1.7818 - val_accuracy: 0.5302
# Epoch 18/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.7588 - accuracy: 0.7316 - val_loss: 1.8909 - val_accuracy: 0.5347
# Epoch 19/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6508 - accuracy: 0.7701 - val_loss: 1.9217 - val_accuracy: 0.5481
# Epoch 20/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6003 - accuracy: 0.7946 - val_loss: 1.7160 - val_accuracy: 0.5436

# %% [markdown]
# ### Model overfit/under-fit (check the accuracy)?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4655 - accuracy: 0.8393
# 14/14 [==============================] - 0s 15ms/step - loss: 1.7160 - accuracy: 0.5436
# Accuracy:  0.8392857313156128
# Validation Accuracy:  0.5436241626739502
# Loss:  0.465471088886261
# Validation Loss 1.7159926891326904

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### **Initial findings**
#
# - In 20 epochs, we can observe the training accuracy is around 83.92%, where as validation accuracy is 54.36%. In terms of training and validation loss, we can observe training loss continuous decreases where as validation loss decreases upto 10 epoch and followed by a sharp increase in loss.
#
# - **Model is overfitting,** as its calculated w.r.t. loss, and we can see the difference between loss in training and validation around 19-20th epoch; At the same we can notice training and validation accuracy

# %% [markdown]
# ### Handle overfitting (Data augmentation)
#
# - Data augmentation can be used in deep learning to handle overfitting. It can be used to generate more sample images by flipping or random rotation

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
from keras.preprocessing.image import ImageDataGenerator

data_aug = keras.Sequential([
       layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
       layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
       layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(10, 10))
for images, labels in  train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_aug(images)[i].numpy().astype("uint8"))
    ax.set_title(class_names[labels[i]])
plt.show()

# %% [markdown]
# ### Retraining the model by using Drop out layer to reduce overfitting

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
input_shape = (180,180,3)
num_classes = 9

model = Sequential([ data_aug,
   layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_5 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_2 (Dense)             (None, 512)               31719936
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 31,827,049
# Trainable params: 31,827,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here
# Train model for more number of epochs to get better accuracy

epochs = 30
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 5s 50ms/step - loss: 1.9503 - accuracy: 0.2846 - val_loss: 1.9988 - val_accuracy: 0.2886
# Epoch 2/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.7825 - accuracy: 0.3471 - val_loss: 1.5870 - val_accuracy: 0.4206
# Epoch 3/30
# 56/56 [==============================] - 3s 46ms/step - loss: 1.6313 - accuracy: 0.4213 - val_loss: 1.5062 - val_accuracy: 0.4832
# Epoch 4/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.5393 - accuracy: 0.4632 - val_loss: 1.5146 - val_accuracy: 0.4832
# Epoch 5/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.4851 - accuracy: 0.4944 - val_loss: 1.4742 - val_accuracy: 0.5145
# Epoch 6/30
# 56/56 [==============================] - 2s 44ms/step - loss: 1.3954 - accuracy: 0.5039 - val_loss: 1.3906 - val_accuracy: 0.5034
# Epoch 7/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.4125 - accuracy: 0.5017 - val_loss: 1.5051 - val_accuracy: 0.4966
# Epoch 8/30
# 56/56 [==============================] - 2s 45ms/step - loss: 1.3955 - accuracy: 0.5000 - val_loss: 1.3843 - val_accuracy: 0.5280
# Epoch 9/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3741 - accuracy: 0.5212 - val_loss: 1.4445 - val_accuracy: 0.5123
# Epoch 10/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3515 - accuracy: 0.5212 - val_loss: 1.3450 - val_accuracy: 0.5503
# Epoch 11/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3655 - accuracy: 0.5285 - val_loss: 1.3996 - val_accuracy: 0.5324
# Epoch 12/30
# 56/56 [==============================] - 3s 46ms/step - loss: 1.3496 - accuracy: 0.5206 - val_loss: 1.3263 - val_accuracy: 0.5145
# Epoch 13/30
# 56/56 [==============================] - 3s 46ms/step - loss: 1.2998 - accuracy: 0.5558 - val_loss: 1.4293 - val_accuracy: 0.5101
# Epoch 14/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3197 - accuracy: 0.5240 - val_loss: 1.3129 - val_accuracy: 0.5347
# Epoch 15/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.3004 - accuracy: 0.5324 - val_loss: 1.3031 - val_accuracy: 0.5414
# Epoch 16/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2458 - accuracy: 0.5541 - val_loss: 1.2967 - val_accuracy: 0.5436
# Epoch 17/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2674 - accuracy: 0.5586 - val_loss: 1.3197 - val_accuracy: 0.5347
# Epoch 18/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2146 - accuracy: 0.5664 - val_loss: 1.3194 - val_accuracy: 0.5213
# Epoch 19/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2858 - accuracy: 0.5458 - val_loss: 1.2923 - val_accuracy: 0.5570
# Epoch 20/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2419 - accuracy: 0.5675 - val_loss: 1.3786 - val_accuracy: 0.5280
# Epoch 21/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2030 - accuracy: 0.5692 - val_loss: 1.3358 - val_accuracy: 0.5391
# Epoch 22/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2007 - accuracy: 0.5658 - val_loss: 1.3393 - val_accuracy: 0.5235
# Epoch 23/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2176 - accuracy: 0.5608 - val_loss: 1.2898 - val_accuracy: 0.5593
# Epoch 24/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1890 - accuracy: 0.5765 - val_loss: 1.3449 - val_accuracy: 0.5459
# Epoch 25/30
# 56/56 [==============================] - 2s 45ms/step - loss: 1.1990 - accuracy: 0.5636 - val_loss: 1.2944 - val_accuracy: 0.5526
# Epoch 26/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1582 - accuracy: 0.5792 - val_loss: 1.2786 - val_accuracy: 0.5503
# Epoch 27/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1337 - accuracy: 0.5954 - val_loss: 1.2906 - val_accuracy: 0.5302
# Epoch 28/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1695 - accuracy: 0.5653 - val_loss: 1.3245 - val_accuracy: 0.5436
# Epoch 29/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1199 - accuracy: 0.5848 - val_loss: 1.2558 - val_accuracy: 0.5861
# Epoch 30/30
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1609 - accuracy: 0.5770 - val_loss: 1.3871 - val_accuracy: 0.5235

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 1s 15ms/step - loss: 1.1071 - accuracy: 0.5904
# 14/14 [==============================] - 0s 16ms/step - loss: 1.3871 - accuracy: 0.5235
# Accuracy:  0.5904017686843872
# Validation Accuracy:  0.5234899520874023
# Loss:  1.1071255207061768
# Validation Loss 1.3871203660964966

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### **Findings**
#
# - With data augmentation strategy, we can see that training and validation accuracy fairly aligns and remain constant, where training and validation loss constantly decreases over period of time.
#
# - Though model accuracy has gone down, but model is not overfitting and requires more hyper parameter tuning. one of the option could be to train for more number of epocs and see the accuracy.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
# - class has least number of samples is 'seborrheic keratosis'
#
#
# #### - Which classes dominate the data in terms proportionate number of samples?
# - Class "pigmented benign keratosis" dominate the data in presence

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.9-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.5)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset = '/content/gdrive/My Drive/cnn-melanoma-detection/Train/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F5DC6036750>: 100%|██████████| 500/500 [00:24<00:00, 20.76 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F5DC6216050>: 100%|██████████| 500/500 [00:25<00:00, 19.49 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F5DC6197E90>: 100%|██████████| 500/500 [00:27<00:00, 17.94 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3072x2304 at 0x7F5DC605DED0>: 100%|██████████| 500/500 [01:42<00:00,  4.87 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F5DC6263190>: 100%|██████████| 500/500 [01:39<00:00,  5.00 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F5DC621B0D0>: 100%|██████████| 500/500 [00:21<00:00, 23.11 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F5DC6250890>: 100%|██████████| 500/500 [00:49<00:00, 10.05 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F5DC605B950>: 100%|██████████| 500/500 [00:22<00:00, 21.85 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F5DC6079A90>: 100%|██████████| 500/500 [00:22<00:00, 21.86 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob

path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027856.jpg_73663343-e650-4608-91b8-9670e44d316a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027269.jpg_fc370f3d-c480-4bb6-9a0a-1091a12a9352.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026693.jpg_155344e7-9e5f-4064-875d-35edaee8e4a1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024867.jpg_538aa0ff-fe9a-4fa8-986f-4905869b8921.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029877.jpg_6caadcd3-34fd-435c-aaf8-b229a5e8bf37.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024662.jpg_9b774dfa-1567-42fa-83c2-f8b59d43d7a1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025578.jpg_5623dd63-3b0c-49b7-9b4a-44b5679cca24.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033092.jpg_49e109e4-bc14-48d1-9834-ec6707c7e0f5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034214.jpg_c87243bd-ba46-43e0-bc8a-ec4b29fa0e86.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026467.jpg_41275c24-6e25-472f-a05c-8da1169f8909.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_83e9d0f3-f81a-49da-bee9-ed22e557cea2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027790.jpg_c9e286c0-7d93-4df7-ae10-29a42da69e10.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_2671de80-a8de-4ffa-89d4-9d68c323eb79.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_620df070-6dfe-40cc-9ace-5f6bce17d030.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024475.jpg_bda6b951-0cc4-439e-b56f-4248457bab74.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_95fb200a-9cbd-4f89-a50d-f11c70af873e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027522.jpg_6adec7a3-bc7b-4884-947c-49d0e5c9752d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031706.jpg_4bb095a0-0bae-4267-85d0-2ddb78376b25.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028406.jpg_c65e9c77-c936-47f4-81f7-62c8bcd5b13b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031346.jpg_d0bd077b-baf2-4e89-8714-ac44988e2382.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031759.jpg_90e1b030-537e-4ff6-bd28-ba0184ca6f2c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_f83a1b41-be67-4cfb-9324-4303fd9996b9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031217.jpg_b54016d3-ff99-45fe-9d4f-109dd6e39a1e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_d8b8407e-7231-472a-a3cd-13c1c173efa3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033158.jpg_121263f9-644c-4ab9-85af-a37b47453629.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032866.jpg_adc701d9-ee26-4f21-a9c0-835244e01a12.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026092.jpg_7e1254fe-894a-476c-8402-a6662193e268.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025677.jpg_d47713dd-3339-43b3-8ba0-ba1b1804eb77.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032919.jpg_7e879247-5cb0-43b0-bbbc-67ec1cfe1665.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027159.jpg_16d9ec52-7388-4ab8-8782-0b0ca7bcce6f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032919.jpg_6bb2438f-a775-4d46-b8d6-a4a3f0fb782c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_11b5bf9f-252e-45ec-85ae-c6ce475918c7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027856.jpg_4869746d-3089-41a1-8cba-1e7f9ff85903.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031197.jpg_43212579-3bfd-4537-88bf-408bd1a5d39a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031901.jpg_802fb532-5a2c-4d5a-88a0-593205fa1ccd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032557.jpg_5ef9d0d0-c26e-4f26-b202-01f332bc6c58.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031201.jpg_74f144d4-4c0d-4725-8f73-a7c310d74979.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033092.jpg_d2b807a5-4d00-4dc4-8095-b874aefac344.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_93ca893b-82b2-4ea0-8e19-f74296254eb3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027210.jpg_f097bb09-3bbd-4176-93cd-fbba18b588f8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_fd2221b8-1d6f-41fe-b6f0-c7699dfd4c27.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_bd4a7327-8521-4d3a-80af-9032e93fffca.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031201.jpg_57abc4cd-e0b7-4239-8a94-1b3cdec4289b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_3c4b5dcd-d4a6-4dd1-a332-9bbc929898b8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032557.jpg_3b9ff91b-5368-4747-9ee7-6c2035cf4e86.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033817.jpg_d7fe45de-1677-4211-befe-605a6156f0ee.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031346.jpg_483e3bbf-926e-4d17-b533-d33c4868675a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025677.jpg_34dbf6f0-fb84-4c5d-9322-48c43920aea5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031996.jpg_41ede9df-2a43-42c0-9ba5-c1294d321b64.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033991.jpg_7e1294d1-4453-4ae5-aa13-9e5d2c50b37d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_dd601887-33b5-48bf-97cb-09d3d473248d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_e521f8a1-e74f-4253-a501-91fe24631fa1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_b3c7422d-4231-45e1-94d5-49db69658f21.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_3bba21c8-d5ca-4cb2-aca8-eeb09e9298e7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026876.jpg_71f38a57-5537-414e-bc6d-15d7992ffecf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031346.jpg_c6958858-6d29-4c07-82b3-3d1b1ec32eec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_cf302b2e-a02b-41ed-9ef6-b3c472413923.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027672.jpg_271820ef-8c56-4534-84af-e2e650dfb9c0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_76304d08-a420-4831-aab9-b96ff6f46930.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025244.jpg_f8ef797a-5a2b-4659-b655-4830fa0d8e4d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033450.jpg_f15e3346-1f52-4868-831d-f3683091f5fe.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025599.jpg_94db07fd-3177-4c05-9a9e-679b9062021b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025628.jpg_53bb50e9-5b1c-4d2a-be92-931745f741ae.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030882.jpg_5f1b0751-0795-4719-9930-39b6390e0013.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_a08791a5-2114-476b-8af2-94a889da4d29.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025197.jpg_0298fd02-c41a-455a-9182-00ab6d9c52a4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032614.jpg_95ea4ed6-6fd8-42e9-8b8a-34636617637f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025249.jpg_5ec68aa3-2325-42ab-b2fe-97af8d49a655.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027672.jpg_714e93a7-b336-4ca5-abb5-763f8be6ccb0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031270.jpg_c2f502d0-041e-49f3-b699-ef21e3c3cb01.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029099.jpg_04feb7ed-ba42-4785-8df4-f328b19321e1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028714.jpg_7c7165fd-3ebc-442d-95a3-21f263a992a7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033450.jpg_978b0414-8a81-4611-8641-7625b615ce05.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031648.jpg_85ded60e-2eaa-4268-95cc-1663bb9c28be.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030104.jpg_37ccb1b9-8d18-46bd-b710-32bbd5f90280.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032692.jpg_2554f257-d11a-4987-bdf9-b6d0362d4d55.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_8abe9862-4d2d-40f3-bff8-bac07e0278cf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031270.jpg_6fc3cd2e-db4c-4865-bcac-b68fce3e7948.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032867.jpg_0f5b1386-d606-4971-9831-19c3a171337f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031719.jpg_44e14680-a671-4cd4-9e51-c12a8b2b3799.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031065.jpg_1dcc55ed-e4c3-4dbd-8c32-c0041a8cf14a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_ac88c5bf-6559-4894-9a3f-d7cd0dfc858c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033591.jpg_29c84b06-f77e-4c32-bcf6-5f4e3a932a06.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033254.jpg_8e7b2d60-c572-47d8-913a-d4a964c7da7e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_50cab6c3-2d0e-4619-9b3f-5be502d58a8e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033092.jpg_644e815c-983a-4012-8302-d649f5bb0918.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025680.jpg_714b4910-6a87-4b3a-8f2b-a958b5ad1b28.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029486.jpg_99c05c25-fb6a-491b-851b-9a77af2e3d55.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031901.jpg_f243a634-59eb-4771-ad27-0617c924a567.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027385.jpg_b4635917-046d-43ef-9f0d-9647c4f44d3e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_e8bb9a9a-c4ca-4871-8ba8-d6dc26935c61.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031270.jpg_a8e696b2-a45d-474f-8c18-5b9e72d5b6d6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_e563734e-fd60-4616-883b-1ed36fcd8bb2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_c1d506ab-89dc-4e47-8f55-022896c16d81.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029448.jpg_8dfc7f60-0923-4014-96c8-5d508381b12b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_a84487d8-9a82-459d-b4e6-513969e8c7a1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027269.jpg_fdd35ded-c2b3-41f0-b2d9-378bbfd92f01.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_f8b35859-6b67-44e5-99f8-dedd70164a5d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_9e750f5f-3746-4204-b836-ce60502d97f1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033991.jpg_61100ecf-6dd4-416e-a40b-7bc8d8d36306.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_415fad0e-e919-4bdc-97f8-257ddc25d74c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030882.jpg_cf5e5892-3357-4f1b-8c47-89a19c61b144.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030722.jpg_3bac2f59-f13c-446b-8200-887de0ba948d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029877.jpg_af7c980e-6fd1-4717-814f-a620291c65fb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026490.jpg_32bd9a22-09c8-4fd5-822c-dd48c563e7f2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_3500bfea-b59e-4983-8aac-48a072919aaf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_178d9fa9-764b-4c07-b075-9480f9adc9e5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026393.jpg_8e8d119d-066b-4ef9-8f28-d97cc0fd9d5c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_9d4f57c3-845c-4063-804b-1bd6557dc3cc.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026456.jpg_00d19ddd-0ca4-495b-a0c5-b605968b67e4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_7369bd09-a3d8-46ef-8ea1-83688d98e422.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028188.jpg_0cf90f05-53e8-462c-a8d5-e101d1abeb1a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026713.jpg_537616fd-9010-46e7-af58-154490b8a65b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031090.jpg_cab620ea-b211-4868-8bba-f5b9f3dad105.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032692.jpg_9fb806c3-e8be-43ea-bd25-c6220cd09096.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028680.jpg_1fe5d1a8-d882-44ff-9459-a5f0370fb86e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_ce6bcebe-338d-44b5-92f4-99aff45096bf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025197.jpg_fba59c37-087c-4c61-95ce-eb3a8d743f2b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032866.jpg_0d0a6b4f-6f2b-486c-93b1-8e2625e7b5d9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031901.jpg_c9092a5e-f771-4c59-9bf4-635b265d0f0a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024662.jpg_01b9fa56-38fd-4591-a146-ddf7fcfbf6b7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_c0dee0ca-dc5e-48bd-90a5-bcd69acdf110.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031706.jpg_743e04d6-e86e-4e91-8ce6-1abfb1a851cc.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027888.jpg_c9ffb7e1-da0f-47ff-81c5-4bb3a90bf850.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028146.jpg_f3ec1704-9caf-422e-9c31-58a81ce89571.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025807.jpg_6704e1e2-8a1c-4bf2-b8d3-bf4cb0feb6c5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032919.jpg_674e88b9-a048-4a30-99b6-811d1eff0e0b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_25babd2d-9e36-43fe-95ec-8da9b13de5c4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025807.jpg_d36973cb-5407-464c-b465-abec7dbb3bf6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_59ec9423-78d6-4ecf-9be7-0a1c10ce4d21.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031215.jpg_4875be7e-2b44-4249-81ab-fb1aa5584a97.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025250.jpg_5cd62803-50c0-4bb7-93ba-99d7c906f4c8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_92361333-71ab-473e-a0c3-2df877c29dc9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033844.jpg_a804bc0c-3a2d-413c-857b-bb60a94541bb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030956.jpg_1d034b00-a874-4296-b5ea-144f73750d2c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033591.jpg_15927dc6-00e0-46ae-b467-c7b510c925c0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027256.jpg_5b6a88d2-f747-4310-a529-0923458862d6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025606.jpg_0c7c6704-4933-4e82-b130-36102b1b33e3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_e9149426-64aa-443f-9061-4749fdef1393.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025578.jpg_0d6832a8-99f8-4747-9ece-1a2940430849.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032932.jpg_fbbd4258-fdad-4aa8-90f8-3f9ef2479521.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033969.jpg_8830050f-3c2f-4450-a78c-9eb10e848bb8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027672.jpg_29f23e2e-9931-4a7b-a6e5-2e5e8e3e2621.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030104.jpg_0adb62b2-85c8-488c-b01d-4e9e14c54496.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032545.jpg_64011cc3-60c3-4bb2-9cc7-44d70dd39d76.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031270.jpg_9224f70b-0e3b-4d13-8766-cf27c11249f6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033158.jpg_dc94d249-e39e-4d99-843b-990ddf78a241.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_df1278cd-9f64-4d4d-95d5-6ae5c47a5502.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031901.jpg_a740d1a2-c3e6-428b-8714-30a019561ef7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_7cc002fe-63f8-4cba-975c-ade878e23150.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029448.jpg_8c774bc8-aba9-4ffe-baa2-67c494887361.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_ae5ae63e-1d67-4ece-94a9-daa7877ab1f3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031955.jpg_04229fe3-d7cc-4619-b384-2c002eb2ff26.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033450.jpg_2f749ab2-4ef4-44d9-96c8-f631fb2ffd30.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029514.jpg_b2a40a63-c49e-479e-b5de-df9581cc6e4d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027256.jpg_20d60166-7191-48f2-8a4b-36d116db8d5e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032240.jpg_7600616f-1321-4fb7-9bc2-5a112371600e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029877.jpg_3ce214cd-d7fb-4ed9-ab59-087a52cc19b1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026876.jpg_123b98e6-1756-4169-b334-254df1a7c92a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026713.jpg_ad1b3c14-b164-4d9e-84f7-2816ffeb358b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_5b49c1d1-c06c-4a6a-9d2f-f13ca79222f0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027672.jpg_ca08aa20-2ac2-42f7-9553-f20b9e312c88.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024747.jpg_65cbf173-6f48-4987-ab02-068d65a27723.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026467.jpg_c25a5f14-d29d-411e-aaac-688a9f611df8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027856.jpg_57b292bf-9efe-4487-81c2-cef073251218.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029889.jpg_a430693a-fa82-474c-9aa8-830fee5048f5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028885.jpg_e444fb44-5c8d-4bc0-8d90-ba9c3507c6d4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026092.jpg_52ccb1b6-3c7f-4895-b57b-7125e1a791a7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032240.jpg_04eda52a-eed8-462f-83ff-e1115536117a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_df3f3ea4-6e66-43be-bc8b-c7d170046092.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028188.jpg_4925eb8f-b423-4cfb-864a-81727316d590.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025606.jpg_03f453fe-6ba9-4208-b3de-473e8efe3f59.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029486.jpg_d9c6bec0-9e2b-4103-8c32-81ca8ba3a748.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032270.jpg_7701e306-f88e-4acc-9984-22e10266d43d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031103.jpg_26834016-09f8-47ff-b40d-191da0b346b7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031719.jpg_89efad55-0e94-4fd8-b4fb-57a6e145ca4e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026490.jpg_d2ea3638-5abb-4210-91c1-7b691c1fe525.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026068.jpg_380ed433-7df1-4954-aae2-d9b55ab3f810.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024747.jpg_1fec5ff2-0d87-49a2-96da-ce89796dcba8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032867.jpg_8ed85e93-14a9-4549-a922-68ba7ef6d635.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_70d80e99-57d9-4e88-a35e-8468342b3fca.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033762.jpg_758311ed-ae4d-481c-8ba3-81e4eed6ebd3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033608.jpg_987c7651-e849-48eb-85fa-4f8d74b0679d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025628.jpg_287805ef-0e3f-40d4-859a-899c23a6c5f9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024747.jpg_958fbdb5-f64c-4d51-8cf5-f527f7238bc6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030722.jpg_2580aba6-fa7f-4aea-b99f-2c5a98c6254c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033135.jpg_c2f21787-5ab7-48c8-a876-ca5a499678b3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_70def096-3ec1-4d2e-bd2b-ae02964fbcf3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_14057393-5dec-451c-8c7b-30d0bc6abaab.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_8c0d54b5-9f9d-4e6a-987b-07b1a31ec0bf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032538.jpg_4316f1b1-3db2-4b39-a58f-4aeeadac4ebd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026393.jpg_9571cc89-7b5d-4b77-89d5-69b383e78dad.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028885.jpg_24a72de7-83ef-4e21-99d3-156c2a73fc11.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032890.jpg_dd1d6dac-4547-418e-a356-5578b41ce517.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033969.jpg_a6d6cdcb-300b-4903-b9ee-6dbe33fe43c3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033608.jpg_470d76f3-dc90-404c-8b80-ec79c5beac00.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026467.jpg_f53eb6e1-7b7a-4193-990c-af8fbb072f7b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_ee7b7b1a-c0a9-47f0-82ef-1e3857ca6d93.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030104.jpg_fe63afe1-f120-4ab3-b1c9-9dc5bc55b31a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_ba300543-9538-42a3-a90b-c698ad70d63f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028163.jpg_58b1c201-26fc-42ee-aeee-137fa23945e6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027269.jpg_bfec8a85-8c03-4244-8a7d-92b268be4b32.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029439.jpg_1616b973-788f-4d82-a699-8793d4113f65.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027790.jpg_b59aabe9-b780-4595-bffd-677ff86cfdf0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033135.jpg_22dd441f-7e4c-4346-8a49-f6863d5049d4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_32095701-f1ee-4769-b055-cd148e6bcd9a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033031.jpg_9d992327-8e09-4fde-af63-8cad8bbb5263.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_50641b36-039b-4a24-b678-5c0514551b13.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028406.jpg_08301ec0-a333-4a96-a0e5-43b6d4d6f0c9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026092.jpg_e2966205-936b-437b-b78c-e7f14dc6282a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_b5c2a6fc-3a79-43ce-8d8b-b2d08a94d93c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030722.jpg_16ad309a-d540-4ce8-b1fd-8925ff5d4260.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033092.jpg_e23298d9-e357-4636-8fcc-4a399804216c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026456.jpg_74b2a689-598b-417b-b8c7-a6b2a903d051.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025321.jpg_dfd64c07-c451-4fc6-84ee-44d9aa71e2a8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030606.jpg_ec04b748-6b57-4b9d-85f9-3d8f5da846c9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033608.jpg_89741cff-2865-40cc-bc78-83e2a2dd9734.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027903.jpg_80263b98-28e9-4e28-8cab-48c793e75665.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033158.jpg_39e6da30-ca02-4454-9af7-ed491edcdfba.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028714.jpg_04783c21-a69b-4862-b37f-93b2e96850ec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029514.jpg_fe7de149-d164-4c43-9d24-ecf712c8cfb4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_3418f449-a5c6-4ce0-9e9a-7ede0151662a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_d2ef493a-0c1a-49a8-8c60-1554c86538d7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_bbe97762-00d2-4cd8-a6fb-12e2021949ae.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029439.jpg_3a168783-4a0c-4008-94a6-ea953bdb1441.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_7a3c605b-09a4-48ec-8912-9ce63bd4c2bf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025244.jpg_abe970de-4db2-4948-a74b-090000cdee4a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033349.jpg_66286731-c8ae-405c-a067-6e5221ac3f58.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029439.jpg_1cf700eb-1731-45d1-b704-47944ac1ea92.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033450.jpg_fc3448e6-1b98-45d6-874d-c3a8a7b2b564.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027159.jpg_ffe19c28-4c76-434e-8046-4199bb87a08e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_1af995af-2c7a-4af7-8df7-def522419ef4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_6eda230d-9be3-4a63-acad-561666dafdff.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030722.jpg_eff6e4fe-7b50-48ce-a168-de2d033fb439.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_aa5d1dcb-c87e-4ed2-8a1e-bc14f08362db.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025628.jpg_5c8c155d-2e3c-4956-a251-a1290f38509e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032745.jpg_a548b96f-5778-4194-bdd5-4ee752567d47.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032240.jpg_8543d002-1867-4b0a-a8e8-c68dadaffab7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025599.jpg_e4504521-11a1-45dd-a464-374e1a4fcbd2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_1173f161-0ac9-40b5-bdc6-d4dc123d3745.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030283.jpg_e85e6498-6be3-4b12-8e70-1f7de95fd717.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025578.jpg_7f0cfac9-5827-4086-8caf-a53101308424.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_fea06bac-d3e5-41f5-96b0-ca45e7058969.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_3252b563-e3ed-4cd1-a370-9b426a1b54ce.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028188.jpg_4201bb48-b35e-4e49-846e-3c9cc31db0be.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_b4f5e13e-d025-45dd-918a-3aca279d7f44.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029099.jpg_847b6135-43b1-4a8b-9123-91b4a388a60f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025680.jpg_dff14b3a-7f24-4044-b3a0-96a4e0f8771e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030606.jpg_b35eb451-78a2-458e-8f64-ea2b8ab5af10.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030882.jpg_70290c07-8c5d-4a55-bec1-1b3987e1040d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026336.jpg_1583267d-3abf-41bb-ae18-48b2cda7c4f1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_923f9bbf-bada-48a7-b42a-05694fa4e3da.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033844.jpg_9afd7a58-1e67-4009-acb0-5fd106f46728.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028146.jpg_6c6791f0-5fbd-4ae6-8d13-de517050e0c5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_2c48c267-cda7-4f1a-8ce5-53872803cbbb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031093.jpg_72f581e1-9066-4a40-96b8-cbe92e93612f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030283.jpg_c972a885-06ac-4425-8011-6013d81579e9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032867.jpg_3f08ae11-9984-44bb-94be-590410308e50.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028406.jpg_81a1efa3-4e8a-4794-9e4c-6e4230fdf57e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_27533db1-8a58-4776-b713-815a909f7966.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_6abc21ea-30ad-4bc8-a4f2-e830603dd288.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025250.jpg_b17cec61-8c99-483c-9252-22b72fe2bac2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029404.jpg_10996e2c-6b05-4022-a8ce-f238df1b3626.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029742.jpg_4473dc65-67a5-472e-8407-107142e4d76e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_47ac6fe0-7e9e-40ce-bdda-913c092e0df3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_57c850b0-3b0d-47a7-b544-df95e4fcbf5e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027385.jpg_47d08406-3ea9-4c2c-8025-b446de666a8d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033591.jpg_e70f754d-73fe-44cb-9bec-7d9c6d61bc1d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025197.jpg_b9f9daca-c9b5-4015-a8e0-a57a40ace41e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033031.jpg_f527c0f2-a9e7-49ea-adeb-76dec86d710d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033969.jpg_0833fedd-8ee1-4768-bbda-d3b0024ec3eb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026490.jpg_0f9ec073-8414-43aa-a2a1-e99df5f28107.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027937.jpg_a1178f4e-4b85-455d-bcc9-1b8906a4aba5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_54159190-faa9-4bdc-a0f7-c8ba7489d6fd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_6a46d7c9-de27-4a74-a0a8-146124aadb2f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_bd24adad-0ee9-4a93-bf3c-a924bc074ae0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029439.jpg_b7de6146-8aed-48f8-b3b5-399f64a2a5fc.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025606.jpg_106ed58b-ec17-430c-8e1f-2cfe30c0efe4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_a85c7924-6e7c-4e39-ad0a-a386fee97c9e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_8116ec30-0c24-4328-b993-5cc9e228bee3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_a9f68fb2-d546-4c05-8b4e-b47185b1e510.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032538.jpg_c3dec596-6b3e-42bb-a535-aaaab5966eec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026490.jpg_f213a561-aef0-42d3-8733-7b129c418db0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032867.jpg_6d89fbd0-955e-41c7-a536-a297091e4c67.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029877.jpg_ef43d394-6466-4a03-8433-a6e9e576a66f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024747.jpg_d1b169c9-b42e-4d8c-ad3a-4322b422ee90.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029486.jpg_82c1663c-ee21-4a73-a475-eef89e66ef71.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026693.jpg_fd0c9bb0-0639-4172-b1ec-2b880aa5bd22.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032866.jpg_304cd86c-e901-46c8-861b-3605f3283c38.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031759.jpg_ba9d3d35-3c8a-461e-98c1-50a35c763eee.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_3fb60886-7c12-4a52-bb33-6b475f8196fd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_92e4c63d-58dc-4bd7-8320-073d42fd7047.jpg',
# ...
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_91ac1834-6565-4047-8a7e-514d8c7506d3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033626.jpg_a84737ba-0173-4c1e-bfed-cb2c52ae6441.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033891.jpg_9fc5201d-d2e0-47b2-a294-55605d9e7177.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030321.jpg_2618b177-ba70-4e0e-b20b-ab18275ebe2d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030321.jpg_1f9f4b52-c2af-46d7-887b-62dbb726c7b3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033808.jpg_fcd887bc-305f-4ec2-9f01-58be9ab277c6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031429.jpg_3aa56657-f811-4cba-87e3-5749ed7008ea.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031443.jpg_437eaefb-6c61-4db4-98d0-018a0baf4212.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025314.jpg_018ede3d-8cd9-44b3-b594-9ce6db313bf1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025302.jpg_57c17cc2-de28-4bc2-907c-954bd1aff97b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027141.jpg_89aca9ff-be03-4c5e-b0f8-4d5669150ce4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029297.jpg_18c45037-3d92-4c9b-8d52-7c05f8d72144.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028346.jpg_0adf9f93-3041-4f80-bf33-9d1c8cc62536.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033847.jpg_37e0c753-0b14-40a1-b518-42f59f2b9101.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029297.jpg_cbc7e8f6-da97-4920-a0e8-efd8df5922b1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029177.jpg_4ddb8540-af93-4d90-bd4c-c8edf2d8b7d5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031271.jpg_05b87e9c-c3bf-409f-a74d-8349df0a9032.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025622.jpg_9bd66154-cb01-41ea-b5ef-a7b7320a4f9e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026473.jpg_aaa1b3c2-197b-4f96-b625-1495e04cb6ad.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027141.jpg_ed491fb2-69d6-416e-bd72-e2226bc4e939.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030757.jpg_e0161327-8467-4c46-8563-e2c9e297737b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025980.jpg_197354d1-17a1-4df4-a262-cda2b0db0e13.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031443.jpg_d9a64a50-0577-4134-bdb3-dc537d9f806b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028346.jpg_c8f7096d-d3c4-44af-b7b9-2a5e9cbbb601.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030555.jpg_e8c8e5b5-ab7d-4f3c-a4a0-08091482ad5a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033790.jpg_f70dbc75-1089-4c90-8ca5-3caadcd371ff.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030011.jpg_ec3e8f97-050f-4160-9f50-64f2beeae4d6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026417.jpg_a841d187-c6c6-4a14-810b-c18d89ce502d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031358.jpg_a7136538-caec-4799-aadd-fa1e8830d4b3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025373.jpg_3fc6ca7a-c404-461f-9a10-6f1761db1d15.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032941.jpg_b29f5604-55c5-45fe-91f2-e0172369ce1c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029248.jpg_4c1659ee-bd7c-4afb-848a-f9c3710f0c8d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027107.jpg_ce92425c-7d30-48f7-ad17-b40e00fadc92.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028346.jpg_2fc8f494-ba6b-4663-8868-772a54981449.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031344.jpg_5b2b6334-677e-4d49-869a-1301e2427e78.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029039.jpg_ea9aacf5-5c6a-4c7e-ac13-c98145a860a3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_22bc8534-241f-4191-a786-e29a0cb8e790.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030665.jpg_635eccdb-c0a6-4196-ab53-1cb823ceb9db.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027876.jpg_dae9e858-2feb-439c-9a6f-cc7aba509959.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026789.jpg_c7184ed7-4454-49a4-8ba6-0adf4509f440.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025771.jpg_6a030097-ed73-40c6-babf-086a0e74e255.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032941.jpg_b417e05b-00a0-4956-b82f-9672b5cf571e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031735.jpg_71da1499-4008-4d7f-b225-59fd239d52bb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028651.jpg_c9196416-9de0-44b3-b983-e1f52aefcbe9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032138.jpg_8467b5f6-0ab6-4504-ae34-3d08e43d5ad9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027008.jpg_5f506ff3-b1e6-4bce-9412-d6a2b9964eee.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032247.jpg_12be2811-d5a5-4fbe-865c-f7d90804b6b7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033554.jpg_cda2d8a6-b49e-477e-b70a-2b8abcbe8aa5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031443.jpg_3382e1ea-593e-4910-9746-2eec3a2ecccd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029177.jpg_4d529e83-e9dd-4567-9963-dcd8eadfb14a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027216.jpg_ab365ab6-dce5-49d8-8013-3d876dba1e3d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030021.jpg_9c464ba7-7245-43d3-ab16-d025885e2c32.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031344.jpg_5dd17a95-47a4-4275-9596-3300a2f44ecf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030757.jpg_d9bf4ef1-fe17-47f7-a365-1fbea4e883b3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031257.jpg_51d2548e-2a17-4968-8f42-f7628ed5151e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025373.jpg_e4e7d1b0-fdd7-4215-b847-0ae6e3c091b1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026471.jpg_aeedbf6d-31d1-4205-994f-718cf1df71af.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028790.jpg_6ec721d4-1518-466b-969f-b129086a33fe.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030665.jpg_f7c6e056-790e-406e-ba1d-81c2140604b2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033695.jpg_51376655-e9a8-4ddb-aab1-b8e7ac57035a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027613.jpg_d03607fd-9bde-425e-b635-d4edac02e9de.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033626.jpg_a28b6c1d-f5d6-4733-bafb-cbc2e39b5370.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033554.jpg_b5c5a8e8-4aa1-4fb6-86da-4e115b1d7826.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025594.jpg_403c313c-c0a2-4024-aca0-a77b5104d204.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030427.jpg_35de7f24-32e1-4ad4-a2e8-17f6939b0c3b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027626.jpg_f9d1774d-8620-48f8-9e9b-5e8f88e97ca8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027216.jpg_06dcaaa5-2a3f-4853-95fc-2c53441132ef.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029039.jpg_46ec3db8-38b8-4146-9456-0a4a128cf4df.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030555.jpg_051e212e-f91f-4fc2-92a7-5fdb8dd97d2a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025622.jpg_90d7df40-9be7-45e3-9574-5bacae30d3b5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031309.jpg_115a46fe-ae30-4d2a-8761-733b355f423c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027488.jpg_438c67ee-4a5a-43ee-a9dd-2e16678a6407.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033808.jpg_0af7bff7-4b74-4aad-9076-f21ced1da095.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_f6dedd95-1bc6-4ff9-83ff-cc68d190dbdf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026473.jpg_1d7dc764-6daa-40f2-b776-5e499aeb216a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032941.jpg_c6d9fd0c-ec67-4c55-8a04-68e2d6091428.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032247.jpg_921a49a9-96a6-4f3e-8d00-56c65cda4e0d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033808.jpg_2dcc05f3-55a8-4032-ba55-6d361292821c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027648.jpg_51599a55-878c-432f-ad2c-58c14861c3e5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028735.jpg_9ec937ce-a5f0-4786-be5b-b13ac39c9a76.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028346.jpg_d27830a8-864a-4383-a20e-5c6a96978c1d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033808.jpg_78f4f0cc-d704-45ef-8306-a8311b86b21d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0034135.jpg_8c30c13f-98e2-4d31-81b9-575ca2f324f7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027648.jpg_0af4984b-b9fe-4768-a0aa-5710e7a24170.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029967.jpg_72b04e05-ee2a-4d84-9413-bf85dbe902ae.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027044.jpg_ba00a99e-754b-42e1-91b4-98075abf6047.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031358.jpg_a64d5e82-e629-42e5-a7fa-acdbc5261e92.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030830.jpg_4cddcd5f-40fe-415a-a0d8-551ee5ab0d81.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_b4ed0f2a-23cf-4daa-aaca-8bf853431405.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026473.jpg_9d659fb7-a6c4-407d-888a-e12764efdb8f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027044.jpg_e2cfbf54-4f29-40aa-a618-056f8900c805.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032642.jpg_9cb25f75-5e80-4624-8064-1b57c25c71e3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025668.jpg_7c48a0d0-4580-41ba-bca1-0a83327373a7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030870.jpg_6e136e49-5da3-4b7a-9e6c-288b28ee7c49.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030442.jpg_26d2d631-86cc-4726-be77-d1a254a95622.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028790.jpg_c119bce2-9f7e-40a4-ae3d-7655920f2dbd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033810.jpg_11849ab5-f9df-4e04-83a6-72f149cc5f4d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025314.jpg_b128f710-4e5e-4e24-9c93-8a551789017d.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
#new_df = original_df.append(df2) ## in upgrad content we can not see original_df
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# vascular lesion               500
# dermatofibroma                500
# melanoma                      500
# nevus                         500
# basal cell carcinoma          500
# squamous cell carcinoma       500
# actinic keratosis             500
# seborrheic keratosis          500
# pigmented benign keratosis    500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train = '/content/gdrive/My Drive/cnn-melanoma-detection/Train/'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset ='training', ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size = (img_height, img_width),
  batch_size = batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation', ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
print(train_ds)
print(val_ds)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

# Rescale the image
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

input_shape = (180,180,3)
num_classes = 9

# Use the batch normalization and drop out to cehck the model

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 512)               31719936
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 31,827,049
# Trainable params: 31,827,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30 
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 169/169 [==============================] - 800s 4s/step - loss: 1.9288 - accuracy: 0.2799 - val_loss: 1.5649 - val_accuracy: 0.3883
# Epoch 2/30
# 169/169 [==============================] - 29s 166ms/step - loss: 1.5441 - accuracy: 0.3986 - val_loss: 1.3955 - val_accuracy: 0.4551
# Epoch 3/30
# 169/169 [==============================] - 29s 165ms/step - loss: 1.4089 - accuracy: 0.4664 - val_loss: 1.2230 - val_accuracy: 0.5427
# Epoch 4/30
# 169/169 [==============================] - 29s 164ms/step - loss: 1.3012 - accuracy: 0.5096 - val_loss: 1.2010 - val_accuracy: 0.5575
# Epoch 5/30
# 169/169 [==============================] - 29s 164ms/step - loss: 1.1823 - accuracy: 0.5478 - val_loss: 1.1800 - val_accuracy: 0.5843
# Epoch 6/30
# 169/169 [==============================] - 29s 165ms/step - loss: 1.0922 - accuracy: 0.5901 - val_loss: 1.0315 - val_accuracy: 0.6080
# Epoch 7/30
# 169/169 [==============================] - 29s 169ms/step - loss: 0.9935 - accuracy: 0.6315 - val_loss: 0.9286 - val_accuracy: 0.6808
# Epoch 8/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.8199 - accuracy: 0.6932 - val_loss: 0.8232 - val_accuracy: 0.7209
# Epoch 9/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.7132 - accuracy: 0.7283 - val_loss: 0.9057 - val_accuracy: 0.6622
# Epoch 10/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.6605 - accuracy: 0.7652 - val_loss: 0.7208 - val_accuracy: 0.7528
# Epoch 11/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.5440 - accuracy: 0.8008 - val_loss: 0.7002 - val_accuracy: 0.7661
# Epoch 12/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.5356 - accuracy: 0.8064 - val_loss: 0.7271 - val_accuracy: 0.7669
# Epoch 13/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.4298 - accuracy: 0.8457 - val_loss: 0.7699 - val_accuracy: 0.7788
# Epoch 14/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.3760 - accuracy: 0.8633 - val_loss: 0.6068 - val_accuracy: 0.8270
# Epoch 15/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.3481 - accuracy: 0.8746 - val_loss: 0.6191 - val_accuracy: 0.8159
# Epoch 16/30
# 169/169 [==============================] - 29s 166ms/step - loss: 0.3166 - accuracy: 0.8852 - val_loss: 0.6586 - val_accuracy: 0.8189
# Epoch 17/30
# 169/169 [==============================] - 29s 166ms/step - loss: 0.2777 - accuracy: 0.8986 - val_loss: 0.6071 - val_accuracy: 0.8344
# Epoch 18/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.2609 - accuracy: 0.9075 - val_loss: 0.6242 - val_accuracy: 0.8122
# Epoch 19/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.2451 - accuracy: 0.9101 - val_loss: 0.5887 - val_accuracy: 0.8382
# Epoch 20/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.2236 - accuracy: 0.9190 - val_loss: 0.7118 - val_accuracy: 0.8218
# Epoch 21/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.2617 - accuracy: 0.9076 - val_loss: 0.6761 - val_accuracy: 0.8174
# Epoch 22/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.2270 - accuracy: 0.9214 - val_loss: 0.7107 - val_accuracy: 0.8322
# Epoch 23/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.2020 - accuracy: 0.9303 - val_loss: 0.6522 - val_accuracy: 0.8515
# Epoch 24/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.1999 - accuracy: 0.9266 - val_loss: 0.6396 - val_accuracy: 0.8456
# Epoch 25/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.1803 - accuracy: 0.9334 - val_loss: 0.6912 - val_accuracy: 0.8434
# Epoch 26/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.2040 - accuracy: 0.9264 - val_loss: 0.7137 - val_accuracy: 0.8389
# Epoch 27/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.1867 - accuracy: 0.9345 - val_loss: 0.7663 - val_accuracy: 0.8293
# Epoch 28/30
# 169/169 [==============================] - 29s 168ms/step - loss: 0.1729 - accuracy: 0.9334 - val_loss: 0.6568 - val_accuracy: 0.8500
# Epoch 29/30
# 169/169 [==============================] - 29s 169ms/step - loss: 0.2052 - accuracy: 0.9327 - val_loss: 0.8184 - val_accuracy: 0.8300
# Epoch 30/30
# 169/169 [==============================] - 29s 167ms/step - loss: 0.1731 - accuracy: 0.9384 - val_loss: 0.6998 - val_accuracy: 0.8278

# %% [markdown]
# ### Model underfit/overfit (Check the accuracy)?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 169/169 [==============================] - 24s 135ms/step - loss: 0.1133 - accuracy: 0.9540
# 43/43 [==============================] - 6s 107ms/step - loss: 0.6998 - accuracy: 0.8278
# Accuracy:  0.9540059566497803
# Validation Accuracy:  0.8277654051780701
# Loss:  0.1132846549153328
# Validation Loss 0.6998247504234314

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# **With class imbalance** and generating some sample images, we can see that training and validation accuracy has gone up. Training accuracy has increased upto > 90% and validation accuracy is around 84%.
#
# With more hyper parameter tunining, accuracy can be increased further.

# %% [markdown]
# ### **Final summary**
#
# - At first, model was overfitting with basic sample images where training accuracy was approx 91% and validation accuracy was 52%
#
# - With basic tuning and help of ImageDataGenerator we were able to train the sample further and model seems to perform better where training and validation accuracy both were close to 60%.
#
# - With class imbalance and generating more sample images, we could notice model improved further and training and validation accuracy both > 80%.
#
# **- With more hyper parameter tuning model can perform better.**

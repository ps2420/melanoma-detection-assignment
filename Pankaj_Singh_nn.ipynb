# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# **The dataset** consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
#
# The data set contains the following diseases:
#
# 1. Actinic keratosis
# 2. Basal cell carcinoma
# 3. Dermatofibroma
# 4. Melanoma
# 5. Nevus
# 6. Pigmented benign keratosis
# 7. Seborrheic keratosis
# 8. Squamous cell carcinoma
# 9. Vascular lesion

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## mount the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Check for default google drive directory
# !ls
# Out:
# gdrive	sample_data

# %% [markdown]
# ### Data Summary
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the root path for train and test images 

root_path = '/content/gdrive/My Drive/cnn-melanoma-detection'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
# Print the number of tran and test images
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Load the train dataset, and use validation_split 0.2 while definiting
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split = 0.2,
    subset = "training",
    seed = 123,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split = 0.2,
    subset = "validation",
    seed = 123,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
#check the tensor shape
print(train_ds)
print(val_ds)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# print the class available in dataset (dataset should consist of 9 classes)

# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.

class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
# Define the test_ds from data_dir_test

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    image_size = (img_height, img_width),
    batch_size = batch_size
  )
# Out:
# Found 118 files belonging to 9 classes.

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    ax.set_title(class_names[labels[i]])
plt.show()

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D, MaxPool2D

# Rescale the image
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

input_shape = (180,180,3)
num_classes = 9

# Use the batch normalization and drop out to cehck the model

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(
    optimizer ='adam', 
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy']
)

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 512)               31719936
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
# =================================================================
# Total params: 31,827,049
# Trainable params: 31,827,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20 
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 604s 2s/step - loss: 2.1703 - accuracy: 0.2126 - val_loss: 1.8823 - val_accuracy: 0.3154
# Epoch 2/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.8374 - accuracy: 0.3209 - val_loss: 1.7896 - val_accuracy: 0.3311
# Epoch 3/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.7883 - accuracy: 0.3638 - val_loss: 1.6201 - val_accuracy: 0.4206
# Epoch 4/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.6783 - accuracy: 0.4090 - val_loss: 1.5657 - val_accuracy: 0.4631
# Epoch 5/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.6156 - accuracy: 0.4347 - val_loss: 1.5538 - val_accuracy: 0.4743
# Epoch 6/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.5318 - accuracy: 0.4626 - val_loss: 1.4911 - val_accuracy: 0.5347
# Epoch 7/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.4205 - accuracy: 0.5017 - val_loss: 1.5487 - val_accuracy: 0.4787
# Epoch 8/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3274 - accuracy: 0.5452 - val_loss: 1.3845 - val_accuracy: 0.5168
# Epoch 9/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3067 - accuracy: 0.5480 - val_loss: 1.3238 - val_accuracy: 0.5526
# Epoch 10/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.2380 - accuracy: 0.5698 - val_loss: 1.3173 - val_accuracy: 0.5503
# Epoch 11/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.2267 - accuracy: 0.5692 - val_loss: 1.3958 - val_accuracy: 0.5436
# Epoch 12/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.1477 - accuracy: 0.5915 - val_loss: 1.3636 - val_accuracy: 0.5459
# Epoch 13/20
# 56/56 [==============================] - 4s 72ms/step - loss: 1.1124 - accuracy: 0.6010 - val_loss: 1.4025 - val_accuracy: 0.5280
# Epoch 14/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.0370 - accuracy: 0.6278 - val_loss: 1.4552 - val_accuracy: 0.5481
# Epoch 15/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.9630 - accuracy: 0.6596 - val_loss: 1.5215 - val_accuracy: 0.5548
# Epoch 16/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.9876 - accuracy: 0.6585 - val_loss: 1.5706 - val_accuracy: 0.5414
# Epoch 17/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.8711 - accuracy: 0.6903 - val_loss: 1.5788 - val_accuracy: 0.5302
# Epoch 18/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.8101 - accuracy: 0.7199 - val_loss: 1.7449 - val_accuracy: 0.5078
# Epoch 19/20
# 56/56 [==============================] - 4s 71ms/step - loss: 0.7162 - accuracy: 0.7589 - val_loss: 1.6768 - val_accuracy: 0.5459
# Epoch 20/20
# 56/56 [==============================] - 4s 72ms/step - loss: 0.7195 - accuracy: 0.7478 - val_loss: 1.7752 - val_accuracy: 0.5548

# %% [markdown]
# ### Model overfit/under-fit (check the accuracy)?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 2s 26ms/step - loss: 0.5013 - accuracy: 0.8158
# 14/14 [==============================] - 0s 25ms/step - loss: 1.7752 - accuracy: 0.5548
# Accuracy:  0.8158482313156128
# Validation Accuracy:  0.5548098683357239
# Loss:  0.5013445615768433
# Validation Loss 1.775154709815979

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Model overfit or Underfit ?

# %% [markdown]
# ### **Initial findings**
#
# - In 20 epochs, we can observe the training accuracy is around 81.56%, where as validation accuracy is 55.84%. In terms of training and validation loss, we can observe training loss continuous decreases where as validation loss decreases upto 10 epoch and followed by a sharp increase in loss.
#
# - **Model is overfitting,** as its calculated w.r.t. loss, and we can see the difference between loss in training and validation around 19-20th epoch; At the same we can notice training and validation accuracy

# %% [markdown]
# ### Handle overfitting (Data augmentation)
#
# - Data augmentation can be used in deep learning to handle overfitting. It can be used to generate more sample images by flipping or random rotation

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
from keras.preprocessing.image import ImageDataGenerator

data_aug = keras.Sequential([
       layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
       layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
       layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(10, 10))
for images, labels in  train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(data_aug(images)[i].numpy().astype("uint8"))
    ax.set_title(class_names[labels[i]])
plt.show()

# %% [markdown]
# ### Retraining the model by using Drop out layer to reduce overfitting

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings
input_shape = (180,180,3)
num_classes = 9

# Use the batch normalization and drop out to cehck the model
 
model = Sequential([ data_aug,
   layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_7 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_24 (Conv2D)          (None, 180, 180, 32)      896
#
#  conv2d_25 (Conv2D)          (None, 180, 180, 32)      9248
#
#  max_pooling2d_17 (MaxPoolin  (None, 90, 90, 32)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 90, 90, 64)        18496
#
#  max_pooling2d_18 (MaxPoolin  (None, 45, 45, 64)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 45, 45, 128)       73856
#
#  max_pooling2d_19 (MaxPoolin  (None, 22, 22, 128)      0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 61952)             0
#
#  dense_12 (Dense)            (None, 512)               31719936
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 9)                 4617
#
# =================================================================
# Total params: 31,827,049
# Trainable params: 31,827,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here
# Train model for more number of epochs to get better accuracy

epochs = 30
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 5s 77ms/step - loss: 2.0787 - accuracy: 0.1992 - val_loss: 2.0442 - val_accuracy: 0.2058
# Epoch 2/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.9627 - accuracy: 0.2545 - val_loss: 1.8799 - val_accuracy: 0.3110
# Epoch 3/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.7363 - accuracy: 0.3722 - val_loss: 1.5934 - val_accuracy: 0.4228
# Epoch 4/30
# 56/56 [==============================] - 4s 74ms/step - loss: 1.6537 - accuracy: 0.3956 - val_loss: 1.6176 - val_accuracy: 0.4340
# Epoch 5/30
# 56/56 [==============================] - 4s 74ms/step - loss: 1.6584 - accuracy: 0.3973 - val_loss: 1.5863 - val_accuracy: 0.4609
# Epoch 6/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.6180 - accuracy: 0.4302 - val_loss: 1.5553 - val_accuracy: 0.4183
# Epoch 7/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5323 - accuracy: 0.4526 - val_loss: 1.4622 - val_accuracy: 0.4877
# Epoch 8/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.5271 - accuracy: 0.4593 - val_loss: 1.5527 - val_accuracy: 0.4564
# Epoch 9/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.4905 - accuracy: 0.4794 - val_loss: 1.4555 - val_accuracy: 0.4877
# Epoch 10/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.4788 - accuracy: 0.4699 - val_loss: 1.6311 - val_accuracy: 0.4497
# Epoch 11/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.4482 - accuracy: 0.4833 - val_loss: 1.4389 - val_accuracy: 0.5034
# Epoch 12/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3917 - accuracy: 0.5156 - val_loss: 1.5982 - val_accuracy: 0.4541
# Epoch 13/30
# 56/56 [==============================] - 4s 80ms/step - loss: 1.4719 - accuracy: 0.4916 - val_loss: 1.4091 - val_accuracy: 0.5101
# Epoch 14/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.4344 - accuracy: 0.5011 - val_loss: 1.3902 - val_accuracy: 0.5101
# Epoch 15/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3551 - accuracy: 0.5285 - val_loss: 1.3514 - val_accuracy: 0.5078
# Epoch 16/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3377 - accuracy: 0.5335 - val_loss: 1.3987 - val_accuracy: 0.5056
# Epoch 17/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3603 - accuracy: 0.5134 - val_loss: 1.3468 - val_accuracy: 0.5257
# Epoch 18/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3163 - accuracy: 0.5312 - val_loss: 1.4433 - val_accuracy: 0.5123
# Epoch 19/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3336 - accuracy: 0.5190 - val_loss: 1.3897 - val_accuracy: 0.5280
# Epoch 20/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3080 - accuracy: 0.5324 - val_loss: 1.4144 - val_accuracy: 0.4966
# Epoch 21/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2763 - accuracy: 0.5396 - val_loss: 1.3646 - val_accuracy: 0.5213
# Epoch 22/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2812 - accuracy: 0.5402 - val_loss: 1.3518 - val_accuracy: 0.5123
# Epoch 23/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2985 - accuracy: 0.5268 - val_loss: 1.4247 - val_accuracy: 0.5302
# Epoch 24/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2811 - accuracy: 0.5458 - val_loss: 1.4490 - val_accuracy: 0.5034
# Epoch 25/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2357 - accuracy: 0.5619 - val_loss: 1.4698 - val_accuracy: 0.4944
# Epoch 26/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2509 - accuracy: 0.5592 - val_loss: 1.3862 - val_accuracy: 0.5011
# Epoch 27/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2202 - accuracy: 0.5714 - val_loss: 1.3253 - val_accuracy: 0.5414
# Epoch 28/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2260 - accuracy: 0.5698 - val_loss: 1.5080 - val_accuracy: 0.5034
# Epoch 29/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2501 - accuracy: 0.5446 - val_loss: 1.3365 - val_accuracy: 0.5436
# Epoch 30/30
# 56/56 [==============================] - 4s 75ms/step - loss: 1.2249 - accuracy: 0.5686 - val_loss: 1.4418 - val_accuracy: 0.5011

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2821 - accuracy: 0.5324
# 14/14 [==============================] - 0s 25ms/step - loss: 1.4418 - accuracy: 0.5011
# Accuracy:  0.5323660969734192
# Validation Accuracy:  0.501118540763855
# Loss:  1.282141089439392
# Validation Loss 1.4418338537216187

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### **Findings**
#
# - With data augmentation strategy, we can see that training and validation accuracy fairly aligns and remain constant, where training and validation loss constantly decreases over period of time.
#
# - Though model accuracy has gone down, but model is not overfitting and requires more hyper parameter tuning. one of the option could be to train for more number of epocs and see the accuracy.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
# - class has least number of samples is 'seborrheic keratosis'
#
#
# #### - Which classes dominate the data in terms proportionate number of samples?
# - Class "pigmented benign keratosis" dominate the data in presence

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.9-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset = '/content/gdrive/My Drive/cnn-melanoma-detection/Train/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F603E14F190>: 100%|██████████| 500/500 [00:19<00:00, 25.76 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F602817CA10>: 100%|██████████| 500/500 [00:20<00:00, 24.10 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F602912C790>: 100%|██████████| 500/500 [00:21<00:00, 23.07 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F61524763D0>: 100%|██████████| 500/500 [01:28<00:00,  5.63 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=824x719 at 0x7F602915BE90>: 100%|██████████| 500/500 [01:23<00:00,  6.01 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F603E020D90>: 100%|██████████| 500/500 [00:17<00:00, 28.73 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F603E020BD0>: 100%|██████████| 500/500 [00:41<00:00, 11.97 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F60282037D0>: 100%|██████████| 500/500 [00:17<00:00, 28.18 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F60B90EE610>: 100%|██████████| 500/500 [00:17<00:00, 28.23 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob

path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033749.jpg_56741da4-4b9b-4209-a00a-d5677a6cca0e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025425.jpg_b2a54b60-3f48-4593-b13e-f4e1735541d0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_0be03df1-c840-4f29-98f7-bfe18d6247da.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_4c1bf3b0-f173-4d35-bdf3-49fc63d2e7b1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029439.jpg_5108b31a-7f43-47b8-af88-51bdd698a201.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026693.jpg_815a9a07-0569-449c-b198-9523aa3715a0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030882.jpg_46c24bb1-9ca8-44de-852c-a592edfc17ec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025249.jpg_37988cae-c8bd-491b-96a2-c91ecffff939.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027888.jpg_02f25e73-58b0-488e-8a03-3cdb1feab69e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025807.jpg_b366aef6-3c38-4f5f-99f2-2652e0b95d9c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033591.jpg_f72975f6-85f6-47c8-bb61-07cf12053b86.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028680.jpg_24aa0626-7ce7-49e0-bd72-67653945e648.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032932.jpg_b03d368b-cda0-4b8a-92cb-6d57bd87aebb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030722.jpg_9e9fccda-bf84-4126-84e8-6b8283107406.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031090.jpg_9fc237b1-8f20-46b5-a4a0-5cbcc52949c5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030283.jpg_b4d0a167-18a3-4ddc-a4b6-9d8ed4cc3eb0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026876.jpg_3f503065-4f36-44b0-87b4-08972a4cc40c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024867.jpg_e75cd225-f8d1-4e8c-9cf7-30229df1a67d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028714.jpg_b68f310a-3f68-471b-9f21-e45200f85325.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026068.jpg_f43d00d5-2901-4017-a2b6-34e565b5f789.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_0dcebd2c-ef0f-4c31-9fa9-5be30ec4a7b8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028163.jpg_9425230f-4688-4adb-ae58-9915a919a068.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033608.jpg_308a2927-57cf-4061-8e71-1ea1cd46600f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030956.jpg_7f6ba16b-6691-4f3a-8e12-1efe62143367.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034214.jpg_74f7497e-ca71-421d-a16e-94b8c042d28e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_822222fc-a563-4769-bd7e-14665b1554ad.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_4f09fa17-1844-4f35-9742-e6bbd6a8fae0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024475.jpg_a45f69c7-295d-44eb-8516-71a470cd6cd1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_6005d60a-386f-4c09-a67d-0b1fcb57c47c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027888.jpg_c1089144-1589-495c-94d4-0df049fd3010.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025596.jpg_637ed46d-6fc8-46d3-92d3-47ba0697dc34.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027856.jpg_87c21d3b-0195-4b71-b6f8-e3d591193398.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_df60137b-e8e5-4472-b797-1d097fbb0413.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025599.jpg_a2e285b9-4962-4c72-8407-e43ab896f09b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_443b5ecc-0fa1-4d6a-8bb0-87ef3cd3f885.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_291e115f-104e-44f2-af3c-7336a78cc6f7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_df1bb2a5-0745-4ea7-91b2-e2de513a8abd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031996.jpg_83c676d6-9fa8-4c89-8de7-0051cf4eb3a3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031215.jpg_591664e1-b030-47b5-ac04-55971f3e813c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_c9d350ba-cdda-45c0-9878-4eb286434cc0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024475.jpg_39013dbd-7603-4e20-883b-24d49545aef6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029404.jpg_8bc0d7ac-e0d4-4eb6-8aea-575f8bfa81b4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_81559761-c9af-4d21-af7d-11ea49746187.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027672.jpg_e1da7404-5320-4adf-857f-d1ede2e930ec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_9522ab02-edd6-49cc-99e1-6c6dbb85c0f4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033254.jpg_6119046e-713a-4a6c-96d1-436277a6524c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029099.jpg_e0d8f8c4-eda8-4bb7-b692-26cd09977268.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026393.jpg_2fb06156-f20e-4d30-b34a-d292bb473068.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_174ca8e0-ad04-4ca5-b2ec-09f1b60177e5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028714.jpg_ada8efc0-260e-438a-bfb3-88d86e42ae10.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033450.jpg_1b887db4-1a8b-41f0-8a3e-b28b7518d707.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033092.jpg_d6d903c8-5e03-4f88-9882-ee8fc31aee69.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030956.jpg_46c2cf24-f220-482b-91ef-b8a89ed0c4a7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034214.jpg_b9fea24e-94a9-412c-be1a-1dfb94c1459a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032890.jpg_8edc1479-8df0-4827-9952-933c62781630.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034214.jpg_adb5a51d-3ecf-4ca0-b3e9-65838e1c8450.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027210.jpg_c5032e17-b7c1-4ce1-bc60-831cac79ec23.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027983.jpg_a9368f0c-1d68-4742-aa3b-4f60985c999f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029404.jpg_9fba7222-2187-4d58-a01d-5ffd15f16122.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034196.jpg_3372c0db-af03-45d0-8dbc-cb0215f08bf4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024662.jpg_cbef975a-fbca-4e01-88cc-7e0d35d47449.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028163.jpg_da935c9a-6815-4857-b33b-30b697011a47.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_f8b4c03b-a24c-41d5-b139-7cbebd72ccd3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025596.jpg_7729de5b-2b1e-4e61-88f3-e3205092831d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029877.jpg_fe46dae4-dc60-41cc-9e9a-56cb6d526621.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_6a8f03d6-e9fc-4be8-a8d7-63104d31013e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033817.jpg_e02eb0c5-03dd-4fdf-bf8d-aa69f28aba16.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_923d19c8-5d86-45cb-85e7-808066400ddb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029514.jpg_dce91431-637d-44fe-a8aa-460bd0092aa1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029099.jpg_9aad187f-a85f-4d3c-9549-1e9176e6e83e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025425.jpg_8438c622-b897-4900-a041-a46b04273509.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_41b6906a-e764-43fc-8ef7-510487b12468.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033591.jpg_8e130f29-0aaa-4a79-b4d3-10f4125ef135.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025250.jpg_99560117-1002-441e-9731-289d428cbb44.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032270.jpg_367387e3-99cb-4726-be07-94daa6f87ab3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_8fda9225-dc2a-4910-ab0b-12f905380584.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_3619f513-9e57-4a2d-b830-7b3f80eddb3f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033254.jpg_024e0495-650a-4257-ba37-d6c8b826aac6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_73988b94-b6ce-4015-9fbf-aa0bd902ccfb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025807.jpg_4a8c4704-4349-4726-894e-aa50e4679230.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031065.jpg_7996c7a2-294a-4bf4-9e91-2c0bf1e631bd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_9a55ea8f-7171-4baa-aeaf-a1ebfee36a18.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032545.jpg_7a7dab16-1e9d-48b0-a4f7-dc0935116070.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026163.jpg_6bc76e5d-08b0-4787-bada-1185ff4eab50.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029514.jpg_b6440a6b-52a6-43af-a041-1f6fb22f0dfe.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025677.jpg_6f2a63e6-5354-44c0-adf6-2b8dfd114080.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032545.jpg_96875b28-823e-4288-8242-2fa8a97c931a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_4beb9926-64d7-48f7-b47b-18cf5ba3813d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031901.jpg_1dcf69cf-ecd8-4eb8-a759-978661396c8f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031103.jpg_daf90218-017a-448f-a865-26a442c86f75.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_7dbde3a6-4438-47ae-a52e-33bfe98b6caf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029889.jpg_45d262d6-4c37-45a1-9cfc-ee34910e58d4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033608.jpg_a5e392c2-0274-4fa5-913c-01f035c2695e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030283.jpg_d4840dd9-5067-4da4-a473-2b1a98d46c86.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028714.jpg_61900a00-f143-4a8c-a660-3378f89fef47.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033031.jpg_fbbcf9fb-821b-4553-aa5c-bbd1f47c47b5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_7514acef-8871-4a70-b8ad-8a7090054a7a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025606.jpg_fa7b717b-ce32-4a6a-b085-94cb889dfbb1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028406.jpg_888d5062-27d9-40f2-9485-0cdd40ca171e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026393.jpg_166f690d-1b11-4d34-aef0-dbfe2cad98dd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031215.jpg_74c860d3-51d6-4f98-bf09-26b7f88a24eb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024867.jpg_03dd6531-b548-47d7-a5b5-0963b684ac79.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032890.jpg_042e6056-a4ab-4780-b9dc-9d59f649a1b8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_00af64da-a384-4d56-bb30-c5bcc8a57985.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025425.jpg_09f6e058-6ea8-4f9f-acad-52c00e5cd2e8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033135.jpg_0c597014-3e2a-4692-884c-c39068dfd5d7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030882.jpg_201af63e-707f-4d77-959c-d052d63bd02b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_7ddd46cd-1bbd-4ce1-ad4e-f0716add1621.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031270.jpg_80883a4a-2e95-448b-8647-c89555457d9f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_d4507c63-1195-4359-914c-7c9a6424daab.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032839.jpg_cd4cb9e8-3e61-4674-9ed8-fef008d3838a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_d2bf150b-84c2-44ed-be0c-088ecbc81f27.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029448.jpg_b50e6528-ff3b-4d89-a09c-844510b654a9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030070.jpg_eb964091-a40b-44b1-9c18-697b2f44d46f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026349.jpg_4561e6a4-749c-4ad3-9770-fb3c8f879698.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031706.jpg_02dc14cf-28de-4449-bb9f-8afa52e6d176.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_84e567ca-8812-4a58-8fe8-93a443254b20.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_a74f2150-6bca-4f99-8b48-7195209ade5f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_151ea6ea-c6cb-42b2-b4cc-065daeeb15a4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026713.jpg_5fc16678-e275-49fe-8494-47cd546d15ba.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025628.jpg_174f7b8f-26ae-43bf-b52a-c705da5ca71d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_c768bdb3-ca86-4015-afdd-af5311d8d63e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032240.jpg_bf618863-9867-47a3-ab96-04ece1d59db9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_397598ba-ba36-4b89-8940-f80431f5fb55.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028146.jpg_c325bb5f-5458-4a22-b05c-24600f84db39.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032745.jpg_6ad2570d-2c12-48b3-b97f-28c62c4dc033.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027159.jpg_db59bf02-74a4-4e91-85bd-3ad964df04c0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029448.jpg_109380d1-5c85-4274-94c3-0e8cbba39d2f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031197.jpg_cbaf8e15-2e2d-44dd-8750-f358c92d6614.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032890.jpg_961aafea-fc3b-45ae-b04e-4f1dd4b0e0f9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032919.jpg_e3675470-2d80-4ced-a840-2721a167e6d2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031648.jpg_babb3814-45b2-4ddf-bedf-8ae4366e6e06.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032076.jpg_ae96c926-e060-4a64-a3a0-a58d997f6820.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_9014f965-09fe-4848-98eb-8dfdbc18e702.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033844.jpg_cc978ede-3a3a-47aa-994a-0e34803db683.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025578.jpg_0ea6e50d-8b53-4f28-8d87-11e063a1e22f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032745.jpg_93c28788-3891-45eb-913b-9b1a47ffcd64.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026467.jpg_04dfa0d0-2ae0-4ee7-8aae-fd4ca82b4015.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_83a7f100-a6b0-485e-85a0-e9d804762514.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027856.jpg_e4463788-74be-441e-b7fe-80552c4d9ece.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031719.jpg_7c053b04-e8d4-42e2-9f94-e188457b8b93.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026349.jpg_1c088497-4ed4-4d03-86ef-37fa1c32f998.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032919.jpg_b0ee5dbf-4526-4ab8-a7f0-4e106446bc72.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030070.jpg_8dab3a77-7616-47a7-896b-d6d3174d6edb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031950.jpg_c6546d70-a2da-49a9-a57a-49c2dcf6f223.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033817.jpg_f3b978e0-9706-4493-9476-cf3ec95927b1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025425.jpg_8850dd80-7f53-4b0d-a4b2-abe8afbd6858.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030606.jpg_0439f9d1-94d7-4efa-af65-32094e452622.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029404.jpg_77278a6a-13bf-4e8c-bca4-bdca14abe129.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024706.jpg_af2f9055-76fd-4239-8abc-1b78a589ea02.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033158.jpg_0b0f32ff-6212-4f0c-8862-ffddb5e238de.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030283.jpg_76470f8c-c713-44be-b2e2-30f61e27dc41.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025249.jpg_725ce2d6-b35b-4d18-b24b-3a93cfec84df.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025596.jpg_6ce9b9c6-e8e7-4644-be01-5693caba2e34.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032614.jpg_fda9ef62-532a-457d-9558-0f27ae48b5c5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032545.jpg_97d76b1f-a13d-4ac5-978e-94fb08eced92.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_227c4aea-036c-4815-b168-9134fa8417a6.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027159.jpg_74cce654-90be-4df6-94c5-0c4dd83fbda2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028188.jpg_0ec177c6-8902-499e-aab9-586da98f0509.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_e1dd33f6-b898-44f9-9ea5-5b9306c00dbf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027888.jpg_a1402263-59da-4370-a1c6-98cbce7e8210.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033135.jpg_16f64707-4443-413b-b7e1-fae3e4fc9c45.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025578.jpg_0ff73465-83da-46db-a5b4-415ffc9c0c11.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032409.jpg_a139584f-84b3-4afb-b2ca-bad761ac3641.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_c09446c9-d810-43eb-aea8-cd6bf82f3a1a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033991.jpg_d7d587e6-c5a2-4e99-a6c5-2a741a0016e3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031197.jpg_8116cec7-57e9-4bed-abf0-b2de944c5e70.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027937.jpg_3d3e7d9a-6bf4-4449-a175-8e86e27b6bb3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025244.jpg_ae5f850c-d1df-48b4-a038-eb079708989e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0034214.jpg_671e9686-2bbe-4649-9ff1-a471a2af8eb4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027937.jpg_213d2d56-2b7a-4900-b15e-39526cc7d9a1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031093.jpg_dab380fb-c5f1-43b6-a465-095381470efd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030606.jpg_3c625127-c297-4356-bcbe-15dda13181a2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033031.jpg_f0313451-739d-4a0f-ba88-ae88fd03c21e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026456.jpg_bc3d5373-093a-4d51-8a39-ab834f370374.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033031.jpg_d54d6d41-fa26-4f5b-a469-31b6360ff3aa.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_3f372bcf-7f0a-4dab-a14f-a771cfed68e8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033991.jpg_b084a154-d171-457d-96da-987ec23502e0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030606.jpg_31ff68e5-6d61-4e57-bfbc-065228d35a59.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025250.jpg_3ceb3676-6d0a-4a8d-8b76-8b58d721909b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025321.jpg_bcc23cdf-e347-4b68-a1ff-c7e9800f53e3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025924.jpg_f39a9eea-d219-43b0-9323-086c50a59ebb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031093.jpg_ae084880-315e-4edb-bfb3-55f530ea5a9a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027522.jpg_5b5b3486-72ad-4fc0-bbc4-7ccf90f1f5f1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025249.jpg_08725c2c-0933-4712-919f-4f98cb04c1c0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032538.jpg_5ca98534-6143-440e-960f-65df2cd17349.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031955.jpg_5b2012c9-b585-49d8-b2bf-555c1cd6de09.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026393.jpg_0908144c-b0f0-4931-9ce8-70d7fe76c9c7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032545.jpg_51529cca-99f8-40ba-9080-e163cec6b0ee.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030770.jpg_af52d64d-f41c-4cab-ab48-d7a273cc70c9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_c5c95251-4ed1-447e-ade8-5e001aaa5395.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032692.jpg_a802e990-8dcc-4d35-8ea6-1183c850d844.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027790.jpg_235fbcca-3022-4051-bda7-c55cb16f6953.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032890.jpg_5f194ea1-ea1b-4491-98c0-1189c986b210.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033254.jpg_76730e8e-da26-4cbc-a53c-6d4faed6f3eb.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_c2f04145-baee-41d6-ac4b-12b8bb07e96c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024475.jpg_652809ec-17dd-4d62-b93a-e8f5a88b60da.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025599.jpg_5635ca36-7ad9-42d3-85d4-87875d7b89af.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024706.jpg_480a9b05-56c8-481b-a25d-3ca9715a9dac.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025596.jpg_7c5ee876-6d32-4f66-a7d0-b5947e0ac936.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_4b3bfbcd-5106-4435-acd4-23a6d515d5ac.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025321.jpg_01b34400-3a69-4c8d-9ab7-111d8daa6a49.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030283.jpg_5c6c5f89-7b56-4a99-8eda-b2ce5cc31c6b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_d3d36322-be63-4e32-a5a8-ad008f09f383.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029889.jpg_494d1c24-0697-4d15-b74e-1d196ae4de0d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026068.jpg_65e3dc68-f9b2-40e5-b2c4-4e9fc254dcec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026349.jpg_c3930f9e-d863-4e81-8d66-be5736d16453.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_64a190dd-8884-4030-a1ad-a1a1fb5c3e5d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025425.jpg_8f180434-d755-4a4b-8636-05a894183fbf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026163.jpg_65d8067d-3d99-4bd6-8104-f77fbc81599d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027159.jpg_47d13ef0-4698-417b-98f9-bc70705cbe9a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027903.jpg_454cfeb6-1547-44c9-af95-b2a4695c47cf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025677.jpg_9d54bdea-e5ab-4d2c-8c57-4a7cec665dd3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025321.jpg_4ee6ac9b-0b19-44d6-a6c8-fc024e9732dc.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024669.jpg_caae6621-1afc-42a3-aa6e-be4356c9a2b4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030275.jpg_83d6b7f7-5c8a-46e5-85ac-c7c7dae2ca38.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029099.jpg_2498b7b0-c5f1-436a-9cc9-c342a6d30629.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024867.jpg_691833af-0baa-4841-b6e1-39e6d0890c87.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031706.jpg_54c1c556-2123-48a8-80c2-5458a41c4d41.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_4a71dae9-9cb1-4d08-95b1-ba6ed78b3c7e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029608.jpg_25d37d1c-09d8-422f-8109-d172a8345721.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027790.jpg_45870ed2-6559-430e-86dc-f51301712bff.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025452.jpg_29e78f90-fc43-405f-8fa5-778689ec95ce.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033031.jpg_fc521336-0453-4794-b230-8d1862e0abfe.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026713.jpg_6d215e1d-bcb2-4f98-97d2-942b97d0016b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025680.jpg_7f24fe62-d4f4-40f3-bb47-973e82cbd68f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_84f41bf9-dd9a-48ca-bbe6-a367be1e28d8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029877.jpg_1d0b2195-318c-4b96-a506-84a86cdd380f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033458.jpg_3aad547a-6b1f-4679-b7bf-bbfb4d0ec610.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031215.jpg_187622eb-0991-47c4-90ff-d8b478170976.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024706.jpg_29a857a3-18c3-4ddb-a336-e1f1f55f028f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_0ea4fdb8-57ec-467a-8cd1-000365761d45.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027665.jpg_e004a9f3-dc34-40bb-bf79-379c6c45af27.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_7e00c576-21d6-48d9-85ea-5671625a7f03.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_904bdc6d-f41b-498b-bd4c-fc27f6549c15.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031276.jpg_e50b6541-a619-4c68-bf79-54d0baf79486.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025873.jpg_bfaa04fe-22ae-440e-815c-6284991c3fc9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026393.jpg_639de1ac-c716-467a-b01b-3ff848cf34a9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031648.jpg_365fa2a1-120b-4adb-bc33-c1d01f558510.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_d282ea82-688e-4cb1-96fe-f63d082d1c1a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_68754af7-2a04-4048-9742-016c2578db7b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026163.jpg_c7fba9cf-0408-430e-a3fb-24886dfc424e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_6f1d3c95-de24-4f49-b86f-dc4866552600.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033762.jpg_156c759a-0c40-4c9f-aa66-b83dab7b5e29.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029486.jpg_201ea8eb-e686-45ab-8624-7c676067b6c1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029514.jpg_488125a9-e1de-4ff9-9ce0-1eb8204b6947.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033991.jpg_3b278773-d291-4d35-9eba-c24ccc54fc13.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029486.jpg_a40523fa-90e7-4d47-be6a-0c8b03ca239d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_b647ff81-2a2e-41fa-8afe-63d273d5eb4b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033123.jpg_f6d00214-c734-484d-b019-b05cc538309b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031093.jpg_f3bd67b6-20b4-4947-aa97-bab8a15d59f2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028885.jpg_8d06771a-9bcf-4347-9ba0-a064c862fa45.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025321.jpg_5ad80c40-68c3-4c17-8023-14d2729339b5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026456.jpg_1107e289-34e0-47ac-b719-ee6d8f68b96d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_33491ee9-6386-41ef-abec-36442709ad6e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024904.jpg_8f0aeaa2-05b1-4900-bfe1-078c886a140b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031215.jpg_b5e4a0ba-d77b-4c78-9622-c496971fade7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026163.jpg_833bc110-15ca-4f95-b75c-5c9baf30cba8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033991.jpg_ff9ba084-c700-445f-9e4f-83cb368b3a15.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031215.jpg_404b1604-b526-48b4-bfa0-99da1ec0d1c0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0030606.jpg_1e9032ae-948f-42a9-bdab-b4d790d1bbf2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025250.jpg_24a69ec4-ed6b-4e7f-8018-9397f29fd422.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031648.jpg_cc111858-0fd4-45e6-a68c-3a3489623839.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027159.jpg_1c5e2ac2-66f0-45c9-8480-c9f772afd661.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031270.jpg_1e54679e-a2c7-49f6-b322-6f8ecdb07778.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025628.jpg_e2b7481f-5449-4d42-9030-d589afd659e4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025707.jpg_8b3ca4f0-0530-488c-acbf-5e7bc52329e7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032692.jpg_29acd647-cfbe-4c56-9144-8da895daca4d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032270.jpg_6bfe5013-13c6-4e13-a9e7-20f619a06fab.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032775.jpg_17f8605b-86f0-4a9e-b8ba-80567668868a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026068.jpg_f9e86d4e-c5bf-4640-afff-176eb8aa110c.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028188.jpg_539c2ff7-4470-4744-9f7f-282f7246d7e4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027210.jpg_c2cb0673-7085-42ed-86e9-15aa04ec9ea8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0029486.jpg_04cc7c57-6ee1-4467-848f-4fab03218a1a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027563.jpg_3aaa5230-0c09-461c-8bbb-7a3be80fe204.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027210.jpg_d3b5b431-8b62-41e6-81c2-64c8a56e2e2a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032715.jpg_63bcb21a-c9cf-452a-8953-0a6e2e9815d4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028714.jpg_8e81fd8b-83c2-4f0c-9b2e-a1aec1940671.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033762.jpg_2fe80345-5f3d-4a3a-989e-3d16f9a5d3d7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033565.jpg_5a4eb40c-4f75-446c-bf9f-9066c7897418.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032057.jpg_3d7b00b6-3aee-4950-8e3e-ebabe1a09a99.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031901.jpg_772bfaf4-a2e5-4ede-8e2f-f2658eeebe9e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032557.jpg_869a52a3-eb4f-4b1d-ad7d-7bdb4a4c3c82.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0028431.jpg_74b63648-3206-4f8c-889c-e2d783224b2a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033749.jpg_c9c60306-21ae-49f1-9996-fe9f43f5692b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0027903.jpg_8274eba4-953c-4530-afa6-9bee3e7d8d20.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0025612.jpg_030b1d70-c0e1-4112-a775-daa6e2b135a8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0033230.jpg_f09863e6-b70d-4997-9f25-34d4d65a7c57.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0024867.jpg_b8d8a819-cf22-4252-a0e1-91f03426bb21.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0032409.jpg_5b73df51-d5fe-4e6a-b1cf-9f222e43333d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0026349.jpg_a2d6fe81-d639-4074-8b88-e7c1e8d83f10.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/vascular lesion/output/vascular lesion_original_ISIC_0031103.jpg_3ffb1b20-8358-41a1-874f-71e29761ba31.jpg',
# ...
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031309.jpg_8eea20d6-4202-4a20-b90b-4187c6bfc636.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031735.jpg_1d9521f1-d25d-44fe-b206-0d4c3f8df37e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_c7d7d536-4f0b-462b-9d30-32cb22f21ec3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_ddef231b-d3fd-4121-9d6b-baac579a1d2e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025903.jpg_c7797ad4-93e7-493a-a8a4-7ca69910a55a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028346.jpg_4b044b20-b786-43be-bfe8-5d3682b401e0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025954.jpg_f1c8e094-db14-4b13-86a0-f9c8ce210ed5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026789.jpg_4270bfeb-3c7c-4a2c-9f4d-1ed34ab8db46.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028346.jpg_e14677ec-640b-49dd-902d-6006f97b1395.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025622.jpg_f449f1a9-274c-41ef-9116-a9f40926d8f8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030870.jpg_5547e4ee-175b-457b-9f3c-f234ec6c374d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027008.jpg_58b7ea69-ab95-4679-9c0f-8863d9af7cce.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032247.jpg_daab7b36-7588-4868-a78e-3e4a233fd459.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029578.jpg_24371c45-83b9-47c0-b9ed-8bfa01a8df8f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031344.jpg_6fe9f0c3-0cb7-47c0-b9ce-ed62d3bcbfad.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031429.jpg_e4e680d4-c5ca-4ca3-adb3-2326137d63dd.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033626.jpg_f2d5dc83-c919-41f6-ab4c-fd196a93d442.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030021.jpg_d7962e06-b316-4d46-8524-9ded102abad8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030011.jpg_e0462a54-386c-4ad1-9f70-82f13f1c5ac2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025903.jpg_9bcc7f34-e57f-4b85-bbbb-95291303dd60.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027598.jpg_c5de8de3-bec6-4c28-83ce-2c951ae2ce08.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_af95c43c-9b8a-4c47-a9c3-a7132cd580bf.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027488.jpg_b6d714e5-f0eb-42a8-9956-225596768857.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033847.jpg_09449aef-2c3b-4354-863e-1f7eac5b77b5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027745.jpg_f31fc601-cd7c-4ed6-b136-ef61e13d1ef1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029578.jpg_4c9ef102-d205-44af-b8a8-3c02dc588b69.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031358.jpg_1749a7b0-9079-4a48-8866-0036e236a3e2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029297.jpg_f6580398-2d78-4e65-8d97-ed357af0eb9a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033810.jpg_f120fd06-47b7-4610-b4cf-eca08fbe54f0.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031457.jpg_f8ee6adc-1607-4564-9e5c-638f5a5ff7d8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026471.jpg_feb600d1-5f0a-4f49-b8a5-1e454dd942e7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025622.jpg_b31c47d8-ad63-4df9-851b-4264213d78e4.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030321.jpg_c4bf2bc3-7a0f-4ff4-9a02-96882e8e4964.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030015.jpg_ec8887da-210c-44a6-a705-1235f67ab0e8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_92d43a95-b281-4ecf-9f39-40844879a90d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029973.jpg_85a94a68-bdc9-4464-a04e-8d961240af78.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031799.jpg_7813b1d3-83cd-4c8e-a3c8-7478cdeca74b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026417.jpg_2e7011b4-0a49-49ab-b948-7e80a644ecae.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028790.jpg_b207214d-35da-44d5-b7f2-3e6cb9ed8a0f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_02e541bd-dbd2-4d44-901c-cfb3f4857e06.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027598.jpg_fa9f8cb4-6169-4734-a633-a70cb5af1bc3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027044.jpg_635946b2-ee22-47c7-9196-ff4618d0e8c8.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027488.jpg_570a1204-a325-4024-94bc-498b2bc463fa.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027216.jpg_5728ea56-3179-41ee-a1b8-a615a9dd7d6b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029783.jpg_6297a375-dfc1-4dc3-a8e0-6b2524b25164.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033780.jpg_86602839-4bb4-4776-aa2f-5b2916e19306.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031344.jpg_d85c01c1-ab9d-4a8b-a26e-08457b745c1a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031429.jpg_efae652a-b79c-4604-beb4-5be4bc5c73e3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029039.jpg_b9e1f00b-ac59-4ee9-9609-b57af4e813ea.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030427.jpg_fef5dc22-cfdb-48ed-b9b7-732553fa4a06.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027626.jpg_90eb6f3f-bc1e-40ac-94f6-e858e67b3459.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031271.jpg_1ed61866-1055-453d-a2d1-e9d7b5be90c7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027216.jpg_6540bf17-1af8-4c6b-a5e0-074e72afb930.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029177.jpg_d3dbde24-998d-45aa-b1a2-4c60ca6b8865.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025980.jpg_1732c335-2f1a-4b77-a89c-e6c8a2fb24d3.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030015.jpg_b1abd915-03d7-49c0-b0f2-501dc8e11208.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032642.jpg_1ee6a755-55b7-4fe2-b84f-b745584c3823.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033005.jpg_fe260a39-d6d4-46af-b199-2e1069c16f3b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031309.jpg_9891b7bb-f680-48a3-911e-2ebce6efce5a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033860.jpg_5a632da5-89c8-4d78-a847-153856f2ef63.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032247.jpg_25ac78b9-bc77-4a5d-926b-d36c841b183a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026471.jpg_185998de-0493-41d2-bce6-489b988418b1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0031443.jpg_d869b52d-d650-4f97-9792-c5fab3cb78fa.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030870.jpg_1e96e14f-a6c2-45c9-bd65-f14712c3f6ea.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033005.jpg_ca45c33f-5983-449b-9756-354e261f0b0b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029130.jpg_8d5b397a-2379-42f1-b7b8-5cb283e9435b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030442.jpg_10690844-c3a2-4706-bc04-7dd6e8bbeb48.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029578.jpg_7acf49ae-beda-4236-958e-bf25357519ff.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033780.jpg_fe4d8bd6-2b50-4960-910d-97ea51cd6055.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027876.jpg_2946ee24-cbfe-4805-8c63-7b634165039d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033626.jpg_b1f038dc-c9de-4ef3-b1f1-a4c5e2e764aa.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026473.jpg_3ff584df-f4ed-48e3-9166-824ac319d491.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025302.jpg_81035610-b63f-41fd-bcfd-2ec822c81078.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029783.jpg_8671ceaa-4636-4f83-af7b-5eaf6b7b3fe9.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_30d0312d-93ba-4a6d-97bc-5b7c2ac674ec.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025622.jpg_19756fbb-0e72-4601-a7ec-ff4fa74718e2.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027598.jpg_04a98f1a-aa10-4c13-8954-beeb1b7c1819.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032468.jpg_1f01ab44-0f6d-4f4d-acaa-f3c5fcb0ff5f.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030427.jpg_0acbbb82-a822-4665-b4fb-df2232ec99ba.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025373.jpg_8106a0a9-6754-4d4c-9a9b-43f545fe9b86.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033675.jpg_5aa524e4-7c5e-4e35-9adb-c8afa658448e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028790.jpg_a2cda96b-62ed-4f8e-9e8c-95f7dfa07da5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026629.jpg_8f7bd0dc-ccb4-420d-9e33-070f7796a1fa.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025622.jpg_c0137cb1-2968-4e5e-83d6-997b9621a6e1.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025223.jpg_fb510220-b7e1-432b-966a-7e9591172fad.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027488.jpg_6dff2f57-f4a0-4616-98d8-eadc36089118.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0027745.jpg_330b9492-b770-4eef-b457-1bc2fcf8bd0b.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0029578.jpg_9159f4a1-99ec-434f-b49f-86f911c23bda.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033005.jpg_55734203-849d-472c-8055-b75f626b3687.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030757.jpg_b6dd6dc7-2d52-47c7-b438-29a8c5c0915e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0025223.jpg_9c141dbc-f7fe-4267-bff3-20397d46b2b7.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0028651.jpg_8494ef7e-f194-40c1-920c-2fa26486ba7d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0026313.jpg_ffb40bcf-7b56-4d1c-853a-10c3f373932d.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0033675.jpg_a7ed3a89-9ed3-4030-b160-67dd891d83b5.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032114.jpg_3a7ef629-41dc-4167-a712-704ea506033a.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0032138.jpg_02175b6f-2c7a-4090-8716-085b310926bc.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030870.jpg_d7705df1-0083-4ba5-9fce-e3e86cf8a10e.jpg',
#  '/content/gdrive/My Drive/cnn-melanoma-detection/Train/dermatofibroma/output/dermatofibroma_original_ISIC_0030015.jpg_734fa3da-769b-4bac-a3db-dd5e50cc332b.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'vascular lesion',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  'dermatofibroma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
#new_df = original_df.append(df2) ## in upgrad content we can not see original_df
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# vascular lesion               500
# dermatofibroma                500
# melanoma                      500
# nevus                         500
# basal cell carcinoma          500
# squamous cell carcinoma       500
# actinic keratosis             500
# seborrheic keratosis          500
# pigmented benign keratosis    500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train = '/content/gdrive/My Drive/cnn-melanoma-detection/Train/'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset ='training', ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size = (img_height, img_width),
  batch_size = batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation', ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
print(train_ds)
print(val_ds)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

# Rescale the image
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

input_shape = (180,180,3)
num_classes = 9

# Use the batch normalization and drop out to cehck the model

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape = input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
          loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
          metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_10 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_29 (Conv2D)          (None, 180, 180, 32)      896
#
#  conv2d_30 (Conv2D)          (None, 180, 180, 32)      9248
#
#  max_pooling2d_20 (MaxPoolin  (None, 90, 90, 32)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 90, 90, 64)        18496
#
#  max_pooling2d_21 (MaxPoolin  (None, 45, 45, 64)       0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 45, 45, 128)       73856
#
#  max_pooling2d_22 (MaxPoolin  (None, 22, 22, 128)      0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 61952)             0
#
#  dense_14 (Dense)            (None, 512)               31719936
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_15 (Dense)            (None, 9)                 4617
#
# =================================================================
# Total params: 31,827,049
# Trainable params: 31,827,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30 
history = model.fit(
  train_ds,
  validation_data = val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 169/169 [==============================] - 32s 184ms/step - loss: 2.0148 - accuracy: 0.2435 - val_loss: 1.5951 - val_accuracy: 0.3779
# Epoch 2/30
# 169/169 [==============================] - 34s 190ms/step - loss: 1.5739 - accuracy: 0.4067 - val_loss: 1.3654 - val_accuracy: 0.4848
# Epoch 3/30
# 169/169 [==============================] - 32s 183ms/step - loss: 1.4441 - accuracy: 0.4629 - val_loss: 1.4001 - val_accuracy: 0.4610
# Epoch 4/30
# 169/169 [==============================] - 32s 181ms/step - loss: 1.3194 - accuracy: 0.5069 - val_loss: 1.1501 - val_accuracy: 0.5731
# Epoch 5/30
# 169/169 [==============================] - 33s 190ms/step - loss: 1.1060 - accuracy: 0.5853 - val_loss: 1.0659 - val_accuracy: 0.6095
# Epoch 6/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.9642 - accuracy: 0.6437 - val_loss: 0.9234 - val_accuracy: 0.6733
# Epoch 7/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.7996 - accuracy: 0.7042 - val_loss: 0.8993 - val_accuracy: 0.6897
# Epoch 8/30
# 169/169 [==============================] - 32s 186ms/step - loss: 0.6794 - accuracy: 0.7595 - val_loss: 0.8547 - val_accuracy: 0.7261
# Epoch 9/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.5650 - accuracy: 0.7969 - val_loss: 0.8279 - val_accuracy: 0.7558
# Epoch 10/30
# 169/169 [==============================] - 31s 180ms/step - loss: 0.4950 - accuracy: 0.8296 - val_loss: 0.8418 - val_accuracy: 0.7506
# Epoch 11/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.4363 - accuracy: 0.8474 - val_loss: 0.7964 - val_accuracy: 0.7661
# Epoch 12/30
# 169/169 [==============================] - 31s 178ms/step - loss: 0.3723 - accuracy: 0.8726 - val_loss: 0.7471 - val_accuracy: 0.7810
# Epoch 13/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.3370 - accuracy: 0.8858 - val_loss: 0.8756 - val_accuracy: 0.7758
# Epoch 14/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.3237 - accuracy: 0.8908 - val_loss: 0.7826 - val_accuracy: 0.7765
# Epoch 15/30
# 169/169 [==============================] - 32s 186ms/step - loss: 0.2629 - accuracy: 0.9078 - val_loss: 0.7483 - val_accuracy: 0.8248
# Epoch 16/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2407 - accuracy: 0.9175 - val_loss: 0.7044 - val_accuracy: 0.8419
# Epoch 17/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.2033 - accuracy: 0.9271 - val_loss: 0.8640 - val_accuracy: 0.7951
# Epoch 18/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2253 - accuracy: 0.9240 - val_loss: 0.8499 - val_accuracy: 0.8203
# Epoch 19/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2185 - accuracy: 0.9234 - val_loss: 0.7277 - val_accuracy: 0.8367
# Epoch 20/30
# 169/169 [==============================] - 32s 182ms/step - loss: 0.3177 - accuracy: 0.8943 - val_loss: 0.8097 - val_accuracy: 0.8181
# Epoch 21/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.2075 - accuracy: 0.9323 - val_loss: 0.7940 - val_accuracy: 0.8174
# Epoch 22/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.1623 - accuracy: 0.9395 - val_loss: 0.7046 - val_accuracy: 0.8411
# Epoch 23/30
# 169/169 [==============================] - 32s 181ms/step - loss: 0.1514 - accuracy: 0.9470 - val_loss: 0.8094 - val_accuracy: 0.8248
# Epoch 24/30
# 169/169 [==============================] - 32s 182ms/step - loss: 0.1594 - accuracy: 0.9395 - val_loss: 0.7420 - val_accuracy: 0.8337
# Epoch 25/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.1607 - accuracy: 0.9436 - val_loss: 0.6829 - val_accuracy: 0.8493
# Epoch 26/30
# 169/169 [==============================] - 32s 182ms/step - loss: 0.1670 - accuracy: 0.9447 - val_loss: 0.9399 - val_accuracy: 0.8018
# Epoch 27/30
# 169/169 [==============================] - 32s 181ms/step - loss: 0.1504 - accuracy: 0.9431 - val_loss: 0.7251 - val_accuracy: 0.8478
# Epoch 28/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1371 - accuracy: 0.9520 - val_loss: 0.7257 - val_accuracy: 0.8382
# Epoch 29/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.1387 - accuracy: 0.9531 - val_loss: 0.8889 - val_accuracy: 0.8174
# Epoch 30/30
# 169/169 [==============================] - 32s 186ms/step - loss: 0.1473 - accuracy: 0.9466 - val_loss: 0.7913 - val_accuracy: 0.8307

# %% [markdown]
# ### Model underfit/overfit (Check the accuracy)?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)
# Out:
# 169/169 [==============================] - 24s 133ms/step - loss: 0.0995 - accuracy: 0.9629
# 43/43 [==============================] - 6s 116ms/step - loss: 0.7913 - accuracy: 0.8307
# Accuracy:  0.9629080295562744
# Validation Accuracy:  0.8307349681854248
# Loss:  0.09948769956827164
# Validation Loss 0.7913369536399841

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# **With class imbalance** and generating some sample images, we can see that training and validation accuracy has gone up. Training accuracy has increased upto > 90% and validation accuracy is around 84%.
#
# With more hyper parameter tunining, accuracy can be increased further.

# %% [markdown]
# ### **Final summary**
#
# - At first, model was overfitting with basic sample images where training accuracy was approx 91% and validation accuracy was 52%
#
# - With basic tuning and help of ImageDataGenerator we were able to train the sample further and model seems to perform better where training and validation accuracy both were close to 60%.
#
# - With class imbalance and generating more sample images, we could notice model improved further and training and validation accuracy both > 80%.
#
# **- With more hyper parameter tuning model can perform better.**
